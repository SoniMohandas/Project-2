# %%
import pandas as pd
import csv
from sqlalchemy import create_engine

# %%
# Loading csv file into dataframe
school_data=pd.read_csv("data/school-distinctive-programmes.csv")

# print school data
school_data.head()
# Out:
#                       school_name              alp_domain  \
# 0        ADMIRALTY PRIMARY SCHOOL                    STEM
# 1      ADMIRALTY SECONDARY SCHOOL                    STEM
# 2    AHMAD IBRAHIM PRIMARY SCHOOL                 Science
# 3  AHMAD IBRAHIM SECONDARY SCHOOL  Languages & Humanities
# 4                  AI TONG SCHOOL                     NaN
#
#                                            alp_title  \
# 0  Design Thinking for Sustainability (DTS @ Admi...
# 1  Design Thinking Through Innovation and Technology
# 2  Sustainability Education ? Nurturing Students ...
# 3         Critical Social Inquiry and Media Literacy
# 4                                                NaN
#
#                               llp_domain1  \
# 0  Community Service & Student Leadership
# 1            Community & Youth Leadership
# 2  Community Service & Student Leadership
# 3              Sports & Outdoor Education
# 4                 Music & Performing Arts
#
# ...

# %%
# Filtering data where alp_domain = STEM
school_data_stem=school_data.loc[school_data.alp_domain=="STEM"]

# %%
try:
    engine = create_engine('postgresql://postgres:postgres@localhost:5432/School_DB')
    conn = engine.connect()
    # Retrieving data from the postgresql database to pandas dataframe
    df = pd.read_sql_query("""SELECT ss.id, ss.school_name, pt.alp_title, lp.llp_domain1, lp.llp_title1
                            FROM stem_school ss
                            JOIN program_title pt
                            ON ss.program_title_id = pt.id
                            JOIN life_program lp
                            ON ss.life_program_id = lp.id
                            WHERE ss.id <= 10;""", conn)
    print(df.head())
    df1 = pd.read_sql_query("""SELECT * FROM stem_school;""", conn)
    print(df1.head())
    
except (exceptions, conn.Error) as error:
    print('Error while connecting to the database')
    
finally:
    if conn:
        conn.close()
        print('Database connection closed')
# Out:
#    id                  school_name  \
# 0   1     ADMIRALTY PRIMARY SCHOOL
# 1   2   ADMIRALTY SECONDARY SCHOOL
# 2   3  ANG MO KIO SECONDARY SCHOOL
# 3   4     BARTLEY SECONDARY SCHOOL
# 4   5      BEATTY SECONDARY SCHOOL
#
#                                            alp_title  \
# 0  Design Thinking for Sustainability (DTS @ Admi...
# 1  Design Thinking Through Innovation and Technology
# 2                   Environment Science & Technology
# 3             Chemical and Life Sciences (Perfumery)
# 4                 Beattyians Think. Create. Innovate
#
#                               llp_domain1  \
# 0  Community Service & Student Leadership
# 1            Community & Youth Leadership
# 2                 Music & Performing Arts
# 3            Community & Youth Leadership
# 4            Community & Youth Leadership
#
#                                           llp_title1
# 0  High Performance Mind-set for Personal Leadership
# 1  Nurturing Mindful Leaders through Community Ou...
# ...
