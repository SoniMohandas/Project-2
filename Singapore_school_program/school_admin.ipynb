# %%
import pandas as pd
import csv
import json
import psycopg2
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func, cast

# %%
# Loading csv file into dataframe
school_data=pd.read_csv("data/school-distinctive-programmes.csv")

# Filtering data 
school_data_stem=school_data.loc[school_data.alp_domain=="STEM"]

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/School_DB')
conn = engine.connect()
school_data.to_sql('school_admin', conn)

# %%
# loading csv files as Reader.
[json.dumps(d) for d in csv.DictReader(open('data/school-distinctive-programmes.csv'))]
# Out:
# ['{"school_name": "ADMIRALTY PRIMARY SCHOOL", "alp_domain": "STEM", "alp_title": "Design Thinking for Sustainability (DTS @ Admiralty)", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "High Performance Mind-set for Personal Leadership", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ADMIRALTY SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Design Thinking Through Innovation and Technology", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Nurturing Mindful Leaders through Community Outreach", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "AHMAD IBRAHIM PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Sustainability Education ? Nurturing Students to be Stewards of Our Environment", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "From Values to Action - Nurturing Community-Based Student Leaders", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "AHMAD IBRAHIM SECONDARY SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "Critical Social Inquiry and Media Literacy", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character Development through Outdoor Learning Experience (OLE)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "AI TONG SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Music & Performing Arts", "llp_title1": "Caring through ARTS", "llp_domain2": "Sports & Outdoor Education", "llp_title2": "Character and Leadership Development through Outdoor Education Programme"}',
#  '{"school_name": "ALEXANDRA PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Science, Design Technology & Design Thinking at ALPS (SDT2@ALPS)", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Cultural Intelligence (CQ) ? The Code of Life", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ANCHOR GREEN PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Empowering Learners to be Environmental Activists (ELEA)", "llp_domain1": "Music & Performing Arts/ Visual Arts & Design", "llp_title1": "A.G.P.S Arts (Aspire, Grow, Passion and Serve through the Arts)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ANDERSON PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Andersonians Living Actively through Values-based Experiences (ALIVE) Programme", "llp_domain2": "Music & Performing Arts", "llp_title2": "Values Inculcation Via Arts and Creative Experiences (VIVACE) @ Anderson"}',
#  '{"school_name": "ANG MO KIO PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "AMKP Leadership-Inspired Values Education (ALIVE)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ANG MO KIO SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Environment Science & Technology", "llp_domain1": "Music & Performing Arts", "llp_title1": "Integrated Arts Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ANGLO-CHINESE SCHOOL (BARKER ROAD)", "alp_domain": "Languages & Humanities", "alp_title": "Developing Effective Communicators through Drama, Debates and Public Speaking", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Building Character through Sports (Basketball, Rugby, Tennis and Water Polo) & Outdoor Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ANGLO-CHINESE SCHOOL (JUNIOR)", "alp_domain": "Interdisciplinary", "alp_title": "Creative Thinkers", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "All for Sports, Sports for All @ ACS (Junior)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ANGLO-CHINESE SCHOOL (PRIMARY)", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Building Character Through Sports", "llp_domain2": "Music & Performing Arts/ Visual Arts & Design", "llp_title2": "The Arts at ACS(P)"}',
#  '{"school_name": "ANGSANA PRIMARY SCHOOL", "alp_domain": "Coding", "alp_title": "Nurturing Problem Solvers through Computational Thinking", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Nurturing and Developing 21st Century Leaders through Enrichment and Lifeskills (ENL) Programmes", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ASSUMPTION ENGLISH SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "Speak English with grAce and Knowledge (SPEAK)", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Community and Youth Leadership", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BARTLEY SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Chemical and Life Sciences (Perfumery)", "llp_domain1": "Community & Youth Leadership", "llp_title1": "i-LEAD @ Bartley (Leadership Experience and Development)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BEACON PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Stimulating Senses Through Science (S3)", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Beacons At Your Service", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BEATTY SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Beattyians Think. Create. Innovate", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Beatty\'s Leaders for Life Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BEDOK GREEN PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Environmental Education (E2@BGPS)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Sports to Reinforce Values Education or STRIVE @ BGPS", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BEDOK GREEN SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "ilnquire. ilnnovate. Developing scientific thinking and inquiry skills through real-life applications", "llp_domain1": "Music & Performing Arts", "llp_title1": "PAssion Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BEDOK SOUTH SECONDARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Project S.H.I.N.E -- An Integrated Student-Centred and Holistic Programme that Develops Innovation and Nurtures Empathy", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "SHAPE @ BDS: A School of Healthy And Physically Educated Enthusiasts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BEDOK VIEW SECONDARY SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "Global Awareness for the 21st Century @ BV", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Good Values @ BV", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BENDEMEER PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Developing Bendemeerians to be Confident Leaders, Rooted in Values", "llp_domain2": "Music & Performing Arts", "llp_title2": "Bendemeer?s TEMPO (Towards Enhancement of Music and Performing Arts Opportunities)"}',
#  '{"school_name": "BENDEMEER SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Making Health Science Alive through Authentic Problem-Based Learning", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Developing Student Leadership Through Service Learning", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BLANGAH RISE PRIMARY SCHOOL", "alp_domain": "STEM", "alp_title": "Aspiring Confident Engineers (ACE)@BRPS", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "The RISE3 (Explore, Empower, Enrich) Outdoor Experience", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BOON LAY GARDEN PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Thinking curriculum through Habits of Mind @ BLGPS - Developing Self-directed Learners", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Environment Education at Boon Lay Garden Primary School", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BOON LAY SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Exploring Possibilities in Materials Science", "llp_domain1": "Music & Performing Arts", "llp_title1": "Music & Performing Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BOWEN SECONDARY SCHOOL", "alp_domain": "Business & Entrepreneurship", "alp_title": "Nurturing Creativity, Empathy and Enterprise through Social Entrepreneurship", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Bowen ChANgemakers Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BROADRICK SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Broadrick Entrepreneurship in STEM", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Confidence And REsilience (CARE) though Aesthetics, Community and Youth Leadership", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BUKIT BATOK SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Developing Proactive Problem-Solvers who care for our World through STEM", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Developing Community Youth Leadership through VIA - Journey to Become RESPECTful Leaders", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BUKIT MERAH SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Creative Robotics and Engineering", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character Development & Leadership through Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BUKIT PANJANG PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Music & Performing Arts", "llp_title1": "i2 Can Dance!", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BUKIT TIMAH PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Inquiry-based Learning Supported by Thinking Routines", "llp_domain1": "Music & Performing Arts", "llp_title1": "Music for Everyone - Building Empathy and Resilience", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BUKIT VIEW PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Developing Thinkers, Collaborators and Communicators", "llp_domain1": "Music & Performing Arts", "llp_title1": "Nurturing Values and Character through Aesthetics", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "BUKIT VIEW SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Clean Energy and Environmental Technology", "llp_domain1": "Music & Performing Arts", "llp_title1": "Learning the Arts, Living the Values", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CANBERRA PRIMARY SCHOOL", "alp_domain": "ICT & Media", "alp_title": "Start Young, Start It Right ? Curating My Learning", "llp_domain1": "Music & Performing Arts", "llp_title1": "Immersing in Canberra Experience through Musical Theatre Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CANBERRA SECONDARY SCHOOL", "alp_domain": "Aesthetics", "alp_title": "Digital Media in Visual Arts", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Active Holistic Health Advocates (AHHAs) Championing Efforts towards a Healthier Community", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CANTONMENT PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "TC@CPS", "llp_domain1": "Music & Performing Arts", "llp_title1": "PAVE @CPS (Performing Art for Values & Excellence)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CASUARINA PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Nature-Based Education", "llp_domain1": "Visual Arts & Design", "llp_title1": "Holistic Education through the ARTS at Casuarina Primary School (HE?ARTS@CAPS)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CATHOLIC HIGH SCHOOL", "alp_domain": "Science", "alp_title": "Coding in Environmental Solutions (CODES)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "VITALS (Values Infused Through Active Learning in Sports)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CEDAR PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Creative and Inventive Thinking (CIT) Programme", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Leadership through Service and Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHANGKAT CHANGI SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Programme SOAR (Student centered Opportunities for AeRospace Industry)", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Service and Leadership through School to Nation", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHANGKAT PRIMARY SCHOOL", "alp_domain": "STEM", "alp_title": "Empathetic towards our Earth and Environment, skilful in Computational thinking with the development of Coding skills, and Opportunity seekers with entrepreneurial dare (ECO@CKP)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Sports, Outdoor, Athletics & Recreation @ Changkat Primary", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHIJ (KATONG) PRIMARY", "alp_domain": "Languages", "alp_title": "Competent, Confident and Respectful Communicators", "llp_domain1": "NULL", "llp_title1": "Community Student Leadership", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHIJ (KELLOCK)", "alp_domain": "Interdisciplinary", "alp_title": "Rethinking Possibilities to Serve the Common Good", "llp_domain1": "Music & Performing Arts", "llp_title1": "ArtsONE+ : Purposeful Learning of Music and Performing Arts Using the Self-regulated Approach", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHIJ OUR LADY OF GOOD COUNSEL", "alp_domain": "Languages", "alp_title": "Drama and Literary Arts for LifE! (D?LitE)", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "The PROACTIVE Leader in Me Development Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHIJ OUR LADY OF THE NATIVITY", "alp_domain": "Languages", "alp_title": "LEAPS (Learn, Engage, Articulate & Perform)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "OLN SPARK (SPorts Active and Resilient Kids)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHIJ OUR LADY QUEEN OF PEACE", "alp_domain": "Science", "alp_title": "Science and Environment Education @ OLQP (SEE @ OLQP)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character Lives In My Behaviour (CLIMB) Through Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHIJ PRIMARY (TOA PAYOH)", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Music & Performing Arts", "llp_title1": "IJ Venture & Values Programme", "llp_domain2": "Sports & Outdoor Education", "llp_title2": "IJSports"}',
#  '{"school_name": "CHIJ ST. JOSEPH\'S CONVENT", "alp_domain": "Languages & Humanities", "alp_title": "The Art of Communication through Theatre and Debates", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Buidling Critical and Creative Thinking through Future-Problem Solving", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHIJ ST. NICHOLAS GIRLS\' SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "A Leader in Every St Nicks Girl (Student Leadership)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHIJ ST. THERESA\'S CONVENT", "alp_domain": "Interdisciplinary", "alp_title": "Education For Life ? Developing Portable Skills through and for Real World Problem Solving", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Developing Self-directed, Confident and Resilient Leaders, Learners and Ladies through Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHONGFU SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Growing Character through Sports and Outdoor Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHONGZHENG PRIMARY SCHOOL", "alp_domain": "Innovation & Enterprise", "alp_title": "EPIC -  Empowering Pupils to Innovate for Community", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Chong Zheng Community Leaders (CZCL)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHRIST CHURCH SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Developing 21st Century Competencies through an Inquiry approach  in Health Science and Technology", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Developing Social Emotional Learning Competencies through Outdoor Adventure Learning", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHUA CHU KANG PRIMARY SCHOOL", "alp_domain": "Coding", "alp_title": "Creative Problem Solving through Robotics", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "A Confident & Caring Leader - Leading Through C.A.R.E", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHUA CHU KANG SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Robotics & Automation for a Better Tomorrow", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Student Leadership", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CHUNG CHENG HIGH SCHOOL (YISHUN)", "alp_domain": "STEM", "alp_title": "Food and Science Technology", "llp_domain1": "Music & Performing Arts", "llp_title1": "Cultivating Values Through Aesthetics", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CLEMENTI PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Visual Arts & Design", "llp_title1": "Instilling Lifelong Learning Through Visual Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CLEMENTI TOWN SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "CODE: COmputing to Discover and Empower", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Leadership Development through Uniformed Groups", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "COMPASSVALE PRIMARY SCHOOL", "alp_domain": "Coding", "alp_title": "Inculcating 21st Century Competencies Through Robotics in Math & Science Curriculum", "llp_domain1": "Music & Performing Arts", "llp_title1": "Developing Aesthetics Appreciation  Through Music Empowerment", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "COMPASSVALE SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Aeronautics Applied Learning Programme", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Inspired North Stars Inspire Actions", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CONCORD PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "E3 Reasoning (Enable, Enrich and Empower) @ Concord", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Outdoor Education@Concord", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "CORPORATION PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Music & Performing Arts", "llp_title1": "Creativity Through Dance", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "DAMAI PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "SPARKS@Play Programme", "llp_domain2": "Music & Performing Arts", "llp_title2": "Empowering Learners Through the Arts"}',
#  '{"school_name": "DAMAI SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Environmental & Health Sciences", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character, Citizenship and Leadership Development through Water Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "DAZHONG PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Music & Performing Arts", "llp_title1": "Developing 21st CC through Arts Education Programme @ Dazhong (AEP@D)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "DE LA SALLE SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Positive Education@DLS: Nurturing Mindful Servant Leaders", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "DEYI SECONDARY SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "Pen it down, Mike it up!", "llp_domain1": "Music & Performing Arts", "llp_title1": "Nurturing Confident Communicators and Gracious Citizens through the Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "DUNEARN SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "FSciTech: Developing Dunearnites as confident and creative young scientists through Food Science and Technology", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Every Dunearnite a Community Youth Leader", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "EAST SPRING PRIMARY SCHOOL", "alp_domain": "ICT & Media", "alp_title": "Digital Creativity @ ESPS", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "SPRING for Life ? Developing Character through Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "EAST SPRING SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "21st Century Innovators through Health Science", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Every Student a Leader Through Service", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "EDGEFIELD PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Environmental Science and Sustainability", "llp_domain1": "Music & Performing Arts", "llp_title1": "Values Inculcation through the Aesthetics", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "EDGEFIELD SECONDARY SCHOOL", "alp_domain": "Business & Entrepreneurship", "alp_title": "Growing the Entrepreneurial Mindset (GEM)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character Education Through Sports (Anchored on Taekwondo)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ELIAS PARK PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Character In Action @ EPPS", "llp_domain2": "Music & Performing Arts", "llp_title2": "Arts Creatively Expressed @ Elias - ACE@Elias"}',
#  '{"school_name": "ENDEAVOUR PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Nurturing Thinkers through Knowledge Building Practices", "llp_domain1": "Music & Performing Arts", "llp_title1": "Every Child A Performer (ECAP)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "EUNOS PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Music & Performing Arts", "llp_title1": "Student Development in the Arts and through the Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "EVERGREEN PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Music & Performing Arts", "llp_title1": "Learning Through the Arts & Learning In the Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "EVERGREEN SECONDARY SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "Developing Effective Communicators, Caring Leaders and Inventive Thinking through National Education", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Strengthening Resilience and Character through Leadership and Sports Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "FAIRFIELD METHODIST SCHOOL (PRIMARY)", "alp_domain": "Languages", "alp_title": "SPEAK (School-wide Programme to Enhance Articulateness among Kids): Pathways to Oracy", "llp_domain1": "Music & Performing Arts", "llp_title1": "HeARTS - Developing empathy and building social awareness through the ARTS", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "FAJAR SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Sustainability through 21st Century Applied Critical and Inventive Thinking Skills (ACIT)", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Rise to Lead", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "FARRER PARK PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "Drama in Education (iDREaM)", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "iCARE - Leaders of Tomorrow", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "FENGSHAN PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Anchored and Driven Leaders through Sports Excellence", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "FERNVALE PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Future Skills Programme", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Greenova - To nurture, innovative, responsible, young environmentalists who love and care for the environment", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "FIRST TOA PAYOH PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "First Clicks - Literacy Through Photography (Visual Arts & Design)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character Building Through Outdoor Experiential Learning", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "FRONTIER PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "Frontier?s Approach to Communicating Effectively", "llp_domain1": "Music & Performing Arts", "llp_title1": "danceFRONT", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "FUCHUN PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "Speak Up! at Fuchun", "llp_domain1": "Music & Performing Arts", "llp_title1": "Aesthetically Responding To Shine (ARTS)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "FUCHUN SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Innovations in Science & Technology for Sustain-Ability", "llp_domain1": "Music & Performing Arts", "llp_title1": "Values Through Dance", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "FUHUA PRIMARY SCHOOL", "alp_domain": "Coding", "alp_title": "Students As Designers for the 21st Century", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Environmental Champions @ FHPS Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "FUHUA SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Forensic Science@Fuhua", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Values in Action, Leadership through Service", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "GAN ENG SENG PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "From Farm to Table", "llp_domain1": "Music & Performing Arts", "llp_title1": "Nurturing Aesthetics and Values Development in Children through Band, Choir and Performing Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "GAN ENG SENG SCHOOL", "alp_domain": "STEM", "alp_title": "GESS Probes Programme", "llp_domain1": "Community & Youth Leadership", "llp_title1": "GESS LIFE Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "GEYLANG METHODIST SCHOOL (PRIMARY)", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "GM Earth Warriors Environment Education (EE): To Develop Student Leaders who Empathise, Enrich and Empower", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "GEYLANG METHODIST SCHOOL (SECONDARY)", "alp_domain": "STEM", "alp_title": "Environmental Science and Sustainable Living", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Nurturing Confident and Compassionate Leaders via Values-in-Action", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "GONGSHANG PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character Through Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "GREENDALE PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Developing Critical and Inventive Thinking Skills through Toy Design", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Developing 21st Century Lifelong Learners through Outdoor Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "GREENDALE SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "SMART Living: Design. Code. Build", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character Development through Outdoor and Adventure Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "GREENRIDGE PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "NE2+ (positive): Nurturing Ethical and Effective Leaders with Positive mind-sets", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "GREENRIDGE SECONDARY SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "The Use of Media in Engaging 21st Century Learners in the English Language Classroom -- Camera. Lights. Action. Programme (CLAP)", "llp_domain1": "Music & Performing Arts / Visual Arts & Design", "llp_title1": "Developing Creative and Confident persons, impacting the community through the Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "GREENWOOD PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "Bilingual LIterature Appreciation Student Series (BLISS)", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "WHIZZ - We are Thinking, Inventive and Zealous KIdZ to serve the community", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "GUANGYANG PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Music & Performing Arts", "llp_title1": "LIVE YOUR PASSION ? developing life-long learners with a passion for Music, Dance and Drama", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "GUANGYANG SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Environmental Science for Sustainable Living", "llp_domain1": "Music & Performing Arts", "llp_title1": "heARTbeat -- Art for Life", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "HAI SING CATHOLIC SCHOOL", "alp_domain": "STEM", "alp_title": "Applied Learning in Robotics and Engineering", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Developing Leadership Competencies in Every HaiSian", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "HAIG GIRLS\' SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Innovation and Service Learning through Integrated Project Work (IPW@HGS)", "llp_domain1": "Music & Performing Arts", "llp_title1": "Character and Leadership through the Performing and Visual Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "HENRY PARK PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Science for Life @ HPPS", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Sports4Life @ HHPS", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "HILLGROVE SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Broadening our Learning Horizons through Flight and Aerospace", "llp_domain1": "Music & Performing Arts", "llp_title1": "Nurturing Confident and Passionate Hillgrovians through the Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "HOLY INNOCENTS\' HIGH SCHOOL", "alp_domain": "Languages", "alp_title": "Journalism and Broadcasting -- Developing Critical Thinkers and Confident Communicators", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Good Samaritan Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "HOLY INNOCENTS\' PRIMARY SCHOOL", "alp_domain": "Coding", "alp_title": "Digiminds@HIPS", "llp_domain1": "Music & Performing Arts", "llp_title1": "ARTistry@HIPS", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "HONG WEN SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Developing 21st Century Learners Holistically through Sports and Games", "llp_domain2": "Community Service & Student Leadership", "llp_title2": "Everyone A Gracious LEader who contributes to Society (EAGLES)"}',
#  '{"school_name": "HORIZON PRIMARY SCHOOL", "alp_domain": "Mathematics", "alp_title": "Computational Thinking in Mathematics", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "I-LEAD ? A Whole School Student Leadership Development Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "HOUGANG PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "X-Cell in Science@HGP ? eXperiment, eXplore, eXperience", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character Development through Outdoor Adventure Education (OAE)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "HOUGANG SECONDARY SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "English Communication Skills through Authentic Learning", "llp_domain1": "Community & Youth Leadership", "llp_title1": "GRC (Gratitude, Respect & Compassion) in Action, a Hougean way of life", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "HUA YI SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Health Sciences: Healthcare technologies for the elderly", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Community and Youth Leadership in Hua Yi", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "HUAMIN PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Education for Sustainable Development (ESD @ Huamin)", "llp_domain1": "NULL", "llp_title1": "Creative Arts Programme for Students (C.A.P.S.)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "INNOVA PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Creative Problem Solving (CPS) Programme: CPS@IPS for the Holistic Development of a 21st Century Child in Innova Primary School", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Leading Through Serving", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "JIEMIN PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "J-YEAR (Jiemin- Young Editors And Reporters )", "llp_domain1": "Music & Performing Arts/ Visual Arts & Design", "llp_title1": "Aesthetics Alive", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "JING SHAN PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Learning Science ? the I3 (Inquiry, ICT & Innovation) Approach", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "FLOURISH @ JSPS ? Developing Character Strengths, Resilience & Mindfulness through VIA", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "JUNYUAN PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "Developing Every Pupil into a Confident Communicator", "llp_domain1": "Music & Performing Arts", "llp_title1": "Mind, Body and Soul", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "JUNYUAN SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Developing Application-based Learning through Food Science", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Cultivating Community Champions through Youth Leadership", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "JURONG PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Every Child a Leader @ JPS (ECAL @ JPS)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "JURONG SECONDARY SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "Environmental Studies: An Inter-disciplinary Approach To Sustainable Urban Living", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Sporty at Heart, Sporting in Mind", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "JURONG WEST PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "Art of Communication for Personal Excellence", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Experiential Learning of Lifeskills for Personal Excellence", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "JURONG WEST SECONDARY SCHOOL", "alp_domain": "Aesthetics", "alp_title": "Harnessing Technology, Communication and the Visual Arts in Authentic Contexts", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Developing Character, Leadership and Citizenship", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "JURONGVILLE SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Real World Learning through Electronics", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Sports for Life - Character Education through Sports Exposure, Sports Empowerment and Sports Excellence", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "JUYING PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "ThINKabits", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Environmental Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "JUYING SECONDARY SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "Developing Confident & Competent Communicators through Oracy Skills Programme", "llp_domain1": "Music & Performing Arts", "llp_title1": "Performing Arts : ?iACE@Juying? (I Appreciate, I Create, I Exhibit at Juying)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "KEMING PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "INquiry Science Projects Involving Research and Experiments (I.N.S.P.I.R.E. the Scientist in Me)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Sports4All@Keming: Character Development through Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "KENT RIDGE SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Developing Computational Thinking through Robotics", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "EVOKE!@KR (Educational Values of Olympism at Kent Ridge) through Sports and Outdoor Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "KHENG CHENG SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Student Voice & Advocacy (SVA) @ KCS", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "KONG HWA SCHOOL", "alp_domain": "Languages", "alp_title": "Every Pupil an Effective Communicator", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Exposure-Experience-Excel through Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "KRANJI PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Nurturing Joyful Learners through Critical and Inventive Thinking", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Developing Champions in Life through Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "KRANJI SECONDARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Nurturing Communities of Reflective and Independent Learners through Thinking Curriculum", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Nurturing a Leader in Every Kranjian through Community and Youth Leadership", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "KUO CHUAN PRESBYTERIAN PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "E-Cube: Engage, Excite, Express", "llp_domain1": "Visual Arts & Design", "llp_title1": "Learning for Life in Art and Design", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "KUO CHUAN PRESBYTERIAN SECONDARY SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "Participate, Access/ Analyse, Create, Evaluate (P.A.C.E) in KCPSS Media Literacy Programme", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Every KCPian a Servant Leader", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "LAKESIDE PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "ThInkers with Heart", "llp_domain1": "Music & Performing Arts", "llp_title1": "ARTS De La Sc?ne", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "LIANHUA PRIMARY SCHOOL", "alp_domain": "Coding", "alp_title": "Robotics Project Work", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "VIA through Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "LOYANG VIEW SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Design and Engineering", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Sports and Outdoor Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "MAHA BODHI SCHOOL", "alp_domain": "Languages", "alp_title": "Empathetic Listeners. Effective Communicators. Trailblazing Advocates (ELECTRA@MBS)", "llp_domain1": "Music & Performing Arts", "llp_title1": "Learning through an Ethnic Arts Programme (LEAP)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "MANJUSRI SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Building Smart Homes with a Big Heart", "llp_domain1": "Music & Performing Arts", "llp_title1": "Learning through the ARTS", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "MARIS STELLA HIGH SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "The Marist Sports & Life Skills Experience", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "MARSILING PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "Spark Ideas, Spark Interest, Spark Action: Igniting A Passion for Purposeful Storytelling (SPARKS@MPS)", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "LEAD (Learn, Engage, Absorb, Demonstrate) to Serve @ MPS", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "MARSILING SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Eco-sustainability through Inquiry-Based Learning", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Values and Character Building through Outdoor Curriculum (VALOUR)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "MARYMOUNT CONVENT SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Sports Excellence (SPEX) @ Marymount", "llp_domain2": "Music & Performing Arts/ Visual Arts & Design", "llp_title2": "Grooming Cultured and Refined Ladies through the Aesthetics"}',
#  '{"school_name": "MAYFLOWER PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "STEM@MFPS", "llp_domain1": "Music & Performing Arts", "llp_title1": "LLP@MFPS: Development of Character, Citizenship and 21CC in and through the Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "MAYFLOWER SECONDARY SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "Developing confidence and curiosity through effective communication", "llp_domain1": "Music & Performing Arts", "llp_title1": "Developing a zest for life through aesthetics", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "MEE TOH SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Educate, Engage and Empower Eco-Citizens @MTS", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "SENCE @ MTS", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "MERIDIAN PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Nurturing Future Learners, Citizens and Leaders through a whole school interdisciplinary approach in Eco-Environmental Curriculum", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Meridian Values-Based Student Leadership In Action For 21CC", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "MERIDIAN SECONDARY SCHOOL", "alp_domain": "Aesthetics", "alp_title": "Aesthetics", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Community and Youth Leadership", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "METHODIST GIRLS\' SCHOOL (PRIMARY)", "alp_domain": "Languages", "alp_title": "Language and Communication", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Outdoor and Sports Programme at MGS", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "MONTFORT JUNIOR SCHOOL", "alp_domain": "Science", "alp_title": "Developing Future Ready Monfortians: I Dream, I Believe, I Make", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character Matters: Developing Montfortians with CHRISTE values through sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "MONTFORT SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Made In Montfort ? Design, Code, Make", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Student Leadership through Outdoor Adventure & Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "NAN CHIAU HIGH SCHOOL", "alp_domain": "STEM", "alp_title": "Electronics in Health Sciences and Health Care Technology", "llp_domain1": "Music & Performing Arts", "llp_title1": "Enhancing Expression, Creativity and Aesthetics Appreciation (ECAA) through the ARTS (Drama, Puppetry and Creative Lyrics Composition)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "NAN CHIAU PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Applied Learning@NCPS through Project Work", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Watch Me Soar (Student Leadership LLP - A Whole School Approach)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "NAN HUA PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "NHPS Thinking Programme", "llp_domain1": "na", "llp_title1": "From ME to WE: Forging the Path to Purpose", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "NANYANG PRIMARY SCHOOL", "alp_domain": "Innovation & Enterprise", "alp_title": "Problem-Solving Through Maker Education", "llp_domain1": "Music & Performing Arts", "llp_title1": "Building Cultural Quotience Through Dance", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "NAVAL BASE PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Holistic Outdoor Physical Education & Sports (HOPES) Programmes", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "NAVAL BASE SECONDARY SCHOOL", "alp_domain": "Aesthetics", "alp_title": "Applied Learning in Art", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character Education through Sports Awareness, Commitment and Empowerment (SpACE)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "NEW TOWN PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "A Leader in Every Child", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "NEW TOWN SECONDARY SCHOOL", "alp_domain": "Aesthetics", "alp_title": "Developing critical and inventive thinkers through visual communication", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Developing Confident & Compassionate Student Leaders to Lead, Serve & Excel", "llp_domain2": "NULL", "llp_title2": "NULL"}',
# ...
#  '{"school_name": "STAMFORD PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Caring for the Community through Interdisciplinary Learning@Stamford Primary School (C2IL@Stamford)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character and Leadership through Sports and Outdoor Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "SWISS COTTAGE SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Applied Sciences for Sustainable Development", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Swiss Thoughtful Leadership Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "TAMPINES NORTH PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Green for Life (G4Life) Programme: Character Building through Environment Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "TAMPINES PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Music & Performing Arts", "llp_title1": "STAR ACTtituDE:Pupils with Strengths, Talents, Aspiration and Resilience to achieve A Character Turnaround and Transformation inspired through Drama in Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "TAMPINES SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Creative Engineering: Inter-disciplinary Authentic Problem Solving", "llp_domain1": "Music & Performing Arts / Visual Arts & Design", "llp_title1": "Creative Expressions: Expressing creatively through visual and performing arts (Arts Education)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "TANGLIN SECONDARY SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "Tanglin P.L.U.S. (Perspectives and Literacies to Understand Society)", "llp_domain1": "Music & Performing Arts / Visual Arts & Design", "llp_title1": "S3 through the Arts@Tanglin Secondary School (TSS)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "TANJONG KATONG PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Team Sports Excellence @ TKP", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "TAO NAN SCHOOL", "alp_domain": "Mathematics", "alp_title": "Application of Mathematics for Lifelong Learning (AML2)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "ENRICH@TNS", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "TECK GHEE PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Visual Arts & Design", "llp_title1": "Confident Communicators with Ceramics (C3)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "TECK WHYE PRIMARY SCHOOL", "alp_domain": "ICT & Media", "alp_title": "Media Whiz Kids! Nurturing Confident and Media Literate Communicators", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "I-LEAD, I-SERVE ? Leadership through and as Service", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "TECK WHYE SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Re-designing the Future with Materials Science", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Sports and Sportsmanship Programme @ TWSS (Experience, Expose, Excel)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "TELOK KURAU PRIMARY SCHOOL", "alp_domain": "Coding", "alp_title": "Innovative Thinking through Coding and Robotics", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Character Development through Team Sports", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "TEMASEK PRIMARY SCHOOL", "alp_domain": "Coding", "alp_title": "RoboALERT (Applicative Learning Experience through Robotics at Temasek)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "SOAR ? Sports Opportunities for Active lifestyle and physical Resilience and Sporting Excellence", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "TOWNSVILLE PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Visual Arts & Design", "llp_title1": "Visual Arts for Life @ Townsville", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "UNITY PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "CAPtivate! ? Critical Thinking Accelerated Programme @ UPS", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "CharGE UP! (Character Development through Green & Experiential Learning @ Unity Primary)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "UNITY SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Inspire through Scientific Innovation and Enterprise", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Lead through Outdoor and Sporting Adventures", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WATERWAY PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "Orators@Waterway", "llp_domain1": "NULL", "llp_title1": "Growth and Benefit Mindset", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WELLINGTON PRIMARY SCHOOL", "alp_domain": "ICT & Media", "alp_title": "Promoting Student Enquiry & Independent Learning through New Media", "llp_domain1": "Music & Performing Arts", "llp_title1": "Developing Student Talent and Life-long Learning in Dance through ADDAM (Academy of Dance, Drama, Art & Music)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WEST GROVE PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Music & Performing Arts", "llp_title1": "Thoughtful Learning through the Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WEST SPRING PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Sustaining the Earth with Applied Solutions (SEAS)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Joyful ExperienC.E. @ West Spring (ExperienC.E. ? Experience Challenging Endeavours)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WEST SPRING SECONDARY SCHOOL", "alp_domain": "Languages & Humanities", "alp_title": "Effective Communication and Critical Thinking through Media Literacy", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "FOCUS (Finding, Optimising, Communicating, Understanding Sports)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WEST VIEW PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "F.R.I.E.N.D of Earth", "llp_domain1": "Music & Performing Arts", "llp_title1": "ACE the Arts (Appreciate, Create, Explore to Excel)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WESTWOOD PRIMARY SCHOOL", "alp_domain": "Innovation & Enterprise", "alp_title": "Positive Design Applied Learning Programme", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Inspiring Student Leadership and Community Service through Positive Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WESTWOOD SECONDARY SCHOOL", "alp_domain": "Business & Entrepreneurship", "alp_title": "Innovation & Social Entrepreneurship", "llp_domain1": "Music & Performing Arts", "llp_title1": "Arts for Life (AfL)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WHITE SANDS PRIMARY SCHOOL", "alp_domain": "ICT & Media", "alp_title": "Digital Media in Aesthetics & Languages", "llp_domain1": "Visual & Performing Arts", "llp_title1": "Visual Art", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WHITLEY SECONDARY SCHOOL", "alp_domain": "Languages", "alp_title": "Speech Communication Arts", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Active Citizenship for Social Change", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WOODGROVE PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "Effective Communication via Drama", "llp_domain1": "Music & Performing Arts", "llp_title1": "Shine and Succeed through Dance", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WOODGROVE SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Materials Science for Sustainable Living", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Learners and Leaders for Life", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WOODLANDS PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "Joy of Learning Languages (JOL2@WOODS)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Sports Performance And Character Education (SPACE)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WOODLANDS RING PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Investigative Project Work @ WRPS", "llp_domain1": "NULL", "llp_title1": "NULL", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WOODLANDS RING SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "The Robotics Education & Enterprise (TREE)", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Student Leadership Development through Involvement in the Community Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "WOODLANDS SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Real Food, Real Science", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Active Glocal Citizens Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "XINGHUA PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Students as Advocates of Environmental Issues in the Community", "llp_domain1": "Visual Arts & Design", "llp_title1": "Developing Higher Order Thinking Through Visual Art", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "XINGNAN PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Xingnan Explorers", "llp_domain1": "Music & Performing Arts", "llp_title1": "FLAIR@XINGNAN ? An experience with Performing Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "XINMIN PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Cultivating a Life of Values and Excellence (CLOVE)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "XISHAN PRIMARY SCHOOL", "alp_domain": "Languages", "alp_title": "News Enrichment Xishanites Unitedly Share (NEXUS)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Empowerment through Sports Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YANGZHENG PRIMARY SCHOOL", "alp_domain": "NULL", "alp_title": "NULL", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Student Leadership and Life Skills Development through Uniformed Groups", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YEW TEE PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "D.R.E.A.M.@Yew Tee (Developing Reflective Learners, Empowering Creative Minds)", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Holistic Enriching and Rewarding Outdoor Education & Sports (HEROES) @ YTPS", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YIO CHU KANG PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "ESTEM@YCKPS (ALP in Environmental STEM-based applied learning AT YCKPS)", "llp_domain1": "Music & Performing Arts", "llp_title1": "CREATE@ YCKPS", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YIO CHU KANG SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Developing inquiring minds and creative learners through Arduino", "llp_domain1": "Music & Performing Arts", "llp_title1": "Growing Character Leadership through Arts, Media and Design", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YISHUN PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Work as a Team, Be Environmentally Green", "llp_domain1": "Music & Performing Arts", "llp_title1": "Viva De Symphonie ? Championing Values: Living, Learning and Growing through Music", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YISHUN SECONDARY SCHOOL", "alp_domain": "Aesthetics", "alp_title": "Sonic Arts ? Applied Learning in Music, Media and Technology", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Leadership for Life", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YU NENG PRIMARY SCHOOL", "alp_domain": "ICT & Media", "alp_title": "The 3E Experience @ YNPS: Nurturing Future-Ready 21st Century Learners", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "GOal GR3IT ? Character Development through Sports @ Yu Neng Primary", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YUAN CHING SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Marine Robotics", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "gRowing Values through Sports and Outdoor Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YUHUA PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Think@Yuhua ? Developing Critical and Creative Thinkers", "llp_domain1": "Music & Performing Arts", "llp_title1": "Building Good Character through Music and the Performing Arts", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YUHUA SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Coding, Design, Thinking and Robotics (CODER)", "llp_domain1": "Music & Performing Arts", "llp_title1": "MELODY- Music Empowered Learners, Our Dynamic Yuhuans", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YUMIN PRIMARY SCHOOL", "alp_domain": "Coding", "alp_title": "I3QUEST ?Question, Imagine, Innovate, Inspire", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Compassionate Champions, Rooted Singaporeans, Citizens of the World ? Developing 21st CC in Yumin Champions", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YUSOF ISHAK SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Programme for Authentic Science, Technology and Environmental Learning", "llp_domain1": "Music & Performing Arts / Visual Arts & Design", "llp_title1": "H2eArts in Tune Programme: History & Heritage through Arts & Music Programme", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "YUYING SECONDARY SCHOOL", "alp_domain": "Business & Entrepreneurship", "alp_title": "Fostering  Inventive and  Critical Thinking through Design Thinking for Enterprising Learners", "llp_domain1": "Community & Youth Leadership", "llp_title1": "Totally Wholesome Engaged and Empowered TeenS (TWEETS)", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ZHANGDE PRIMARY SCHOOL", "alp_domain": "Science", "alp_title": "Developing Zhangde GIVER3S Values Through Environment Education", "llp_domain1": "NULL", "llp_title1": "NULL", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ZHENGHUA PRIMARY SCHOOL", "alp_domain": "Interdisciplinary", "alp_title": "Advocates and Innovators for Sustainable Living", "llp_domain1": "Music & Performing Arts", "llp_title1": "Aesthetics Appreciation through Dance Arts Education", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ZHENGHUA SECONDARY SCHOOL", "alp_domain": "STEM", "alp_title": "Game Design and Simulation and Robotics", "llp_domain1": "Sports & Outdoor Education", "llp_title1": "Outdoor Education for Character & Leadership Development", "llp_domain2": "NULL", "llp_title2": "NULL"}',
#  '{"school_name": "ZHONGHUA PRIMARY SCHOOL", "alp_domain": "STEM", "alp_title": "ZPS STE(A)M ? Thinknovate", "llp_domain1": "Community Service & Student Leadership", "llp_title1": "Green Education Movement @ Zhonghua Primary School (GEM@ZPS)", "llp_domain2": "NULL", "llp_title2": "NULL"}']

# %%
from urllib import request
